# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fname='tau_p.txt'
data1 = np.genfromtxt(fname, delimiter='\t', skip_header=1)
fix, ax = plt.subplots()
x, y, color = data1[:,0], data1[:, 1], data1[:,2]
line = ax.scatter(x, y, c=color, s=1 , cmap='magma',)
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
plt.title('Peak position map')
# Out:
# Text(0.5, 1.0, 'Peak position map')

# %%
fname='tau_p_1.txt'
data2 = np.genfromtxt(fname, delimiter='\t', skip_header=1)
fix, ax = plt.subplots()
x, y, color = data2[:,0], data2[:, 1], data2[:,2]
line = ax.scatter(x, y, c=color, s=2, cmap='magma',)
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
plt.title('Peak position map')
plt.show()

# %%
fname='tau_p_4.txt'
data3 = np.genfromtxt(fname, delimiter='\t', skip_header=1)
fix, ax = plt.subplots()
x, y, color = data3[:,0], data3[:, 1], data3[:,2]
line = ax.scatter(x, y, c=color, s=1, cmap='magma',)
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
plt.title('Peak position map')
plt.colorbar(line, ax=ax)
plt.show()

# %%
plt.show()
fname = 'tau_p_6.1.txt'
data3 = np.genfromtxt(fname, delimiter='\t', skip_header=1)
fix, ax = plt.subplots()
x, y, color = data3[:, 0], data3[:, 1], data3[:, 2]
line = ax.scatter(x, y, c=color, s=0.05, cmap='magma', )
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
plt.title('Peak position map')
plt.colorbar(line, ax=ax)
plt.show()

# %%
data = np.vstack((data1, data2))
fig, ax = plt.subplots()
ind = np.logical_and(data[:,1]<200,data[:,0]<4)
data = data[ind, :]
x, y, color = data[:,0], data[:, 1], data[:,2]
line = ax.scatter(x, y, c=color, s=2, cmap='magma')
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
plt.title('Peak position map')
plt.colorbar(line, ax=ax)
plt.show()

# %%
fname='tau_p_7.txt'
data3 = np.genfromtxt(fname, delimiter='\t', skip_header=1)
fix, ax = plt.subplots()
x, y, color = data3[:,0], data3[:, 1], data3[:,2]
line = ax.scatter(x, y, c=color, s=0.1, cmap='magma',)
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
# ax.semilogx()
# ax.semilogy()
plt.title('Peak position map')
cbar = plt.colorbar(line, ax=ax)
cbar.set_label(r'$r_{max}$')
plt.show()

# %%
fname='tau_p_7.txt'
data3 = np.genfromtxt(fname, delimiter='\t', skip_header=1)
index = np.logical_and(data3[:,0]<4, data3[:,1]<500)
data3 = data3[index]
fix, ax = plt.subplots()
x, y, color = data3[:,0], data3[:, 1], data3[:,2]
line = ax.scatter(x, y, c=color, s=0.5, cmap='magma',)
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
# ax.semilogx()
# ax.semilogy()
plt.title('Peak position map')
plt.colorbar(line, ax=ax)
plt.show()

# %%
fname='tau_p_7.txt'
data3 = np.genfromtxt(fname, delimiter='\t', skip_header=1)
fix, ax = plt.subplots()
index = data3[:,0]>1e-1
data3 = data3[index]
x, y, color = data3[:,0], data3[:, 1], data3[:,2]

line = ax.scatter(x, y, c=color, s=1, cmap='magma',)
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
ax.semilogx()
ax.semilogy()
plt.title('Peak position map')
plt.colorbar(line, ax=ax)
plt.show()

# %%
fname='tau_p_7.txt'
data3 = np.genfromtxt(fname, delimiter='\t', skip_header=1)
index = np.logical_and(data3[:,2]<0.84, data3[:,2]>0.83)
data3 = data3[index]
fix, ax = plt.subplots()
x, y, color = data3[:,0], data3[:, 1], data3[:,2]
line = ax.scatter(x, y, c=color, s=0.5, cmap='magma',)
ax.set_xlabel(r'$p_{out}$')
ax.set_ylabel(r'$tau_r$')
# ax.semilogx()
# ax.semilogy()
plt.title('Peak position map')
plt.colorbar(line, ax=ax)
plt.show()
