# %%
import numpy as np
import matplotlib.pyplot as plt
from processclass import Experiment2D
from program import loop_param, plot, plot_r_max
from main import get_r_max, get_peak, get_peak_twinning, get_r_maxes

# %%
pr = Experiment2D()
# Initializing model
pr.n0 = 2.7  # 1/nm^2
pr.F = 730.0  # 1/nm^2/s
pr.s = 1.0
pr.V = 0.05  # nm^3
pr.tau = 200e-6  # s
pr.D = 8e5  # nm^2/s
pr.sigma = 0.02  # nm^2
pr.f0 = 1.0e7
pr.fwhm = 50  # nm
pr.order = 1
pr.step = 0.3  # nm

# %%
# vals = np.arange(50e-6, 500e-6, 20e-6).round(6)
vals = np.arange(142.5e-6, 143e-6, 0.02e-6).round(8)
param_name = 'tau'
exps = loop_param(param_name, vals, pr)
r_max, twin_peak = get_r_maxes(exps)
# Out:
# 33383it [00:00, 41723.39it/s]
# 33381it [00:00, 43872.07it/s]
# 33378it [00:00, 43954.82it/s]
# 33375it [00:00, 44294.46it/s]
# 33373it [00:00, 43709.30it/s]
# 33370it [00:00, 44125.28it/s]
# 33368it [00:00, 42616.88it/s]
# 33365it [00:00, 42117.73it/s]
# 33363it [00:00, 41514.33it/s]
# 33360it [00:00, 42028.90it/s]
# 33357it [00:00, 42667.13it/s]
# 33355it [00:00, 42524.29it/s]
# 33352it [00:00, 43083.30it/s]
# 33350it [00:00, 42793.53it/s]
# 33347it [00:00, 42638.50it/s]
# 33344it [00:00, 43380.94it/s]
# 33342it [00:00, 40230.29it/s]
# 33339it [00:00, 40765.93it/s]
# 33337it [00:00, 41950.44it/s]
# 33334it [00:00, 42682.96it/s]
# 33331it [00:00, 42520.90it/s]
# 33329it [00:00, 43039.53it/s]
# 33326it [00:00, 42801.31it/s]
# 33324it [00:00, 43000.01it/s]
# 33321it [00:00, 43285.81it/s]
# 33318it [00:00, 42738.38it/s]

# %%
r_max, twin_peak = get_r_maxes(exps)

# %%
plot(exps, param_name, 'p_i', 'Diffusion path at the beam center vs Residence time', twin_peak)

# %%
plot(exps, param_name, 'p_o', 'Diffusion path outside of BIR vs Residence time', twin_peak)

# %%
plot(exps, param_name, 'tau_r', 'Relative depletion vs Residence time', twin_peak)

# %%
plot_r_max(exps, r_max, param_name, 'Peak position vs residence time', twin_peak)

# %%
plot_r_max(exps, r_max, 'p_i', 'Peak position vs diffusion path at the beam center', twin_peak)

# %%
plot_r_max(exps, r_max, 'p_o', 'Peak position vs diffusion path outside of BIR', twin_peak)

# %%
plot_r_max(exps, r_max, 'tau_r', 'Peak position vs diffusion path outside of BIR', twin_peak)
