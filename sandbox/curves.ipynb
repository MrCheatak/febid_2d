# %%
import main

# %%
pr = main.pr
pr.n0 = 2.7  # 1/nm^2
pr.F = 730.0  # 1/nm^2/s
pr.s = 1.0
pr.V = 0.05  # nm^3
pr.tau = 200e-6  # s
pr.D = 8e5  # nm^2/s
pr.sigma = 0.02  # nm^2
pr.f0 = 1.0e7
pr.fwhm = 50  # nm
pr.order = 1
pr.step = 0.5  # nm

# %%
r, R, n, r_max = main.r_max_vs_D()
# Out:
# 1000it [00:00, 45454.88it/s]
# 9408it [00:00, 50558.71it/s]
# 9428it [00:00, 50670.02it/s]
# 9449it [00:00, 50733.87it/s]
# 9469it [00:00, 51025.71it/s]
# 9489it [00:00, 51344.12it/s]
# 9509it [00:00, 50173.46it/s]
# 9610it [00:00, 51790.98it/s]
# 9711it [00:00, 50975.73it/s]
# 9811it [00:00, 51367.65it/s]
# 9911it [00:00, 50769.11it/s]
# 10792it [00:00, 51054.80it/s]
# 12746it [00:00, 42298.36it/s]
# 14800it [00:00, 50653.78it/s]
# 16799it [00:00, 48842.92it/s]
# 22497it [00:00, 49695.98it/s]
# 32872it [00:00, 50427.42it/s]
# 42982it [00:00, 50782.71it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
r, R, n, r_max = main.r_max_vs_f0()
# Out:
# 18728it [00:00, 51875.88it/s]
# 18624it [00:00, 51672.57it/s]
# 18580it [00:00, 51462.22it/s]
# 18587it [00:00, 50503.17it/s]
# 18619it [00:00, 50931.18it/s]
# 18657it [00:00, 50831.25it/s]
# 18689it [00:00, 50403.78it/s]
# 18712it [00:00, 50189.20it/s]
# 18727it [00:00, 49036.45it/s]
# 18738it [00:00, 49182.24it/s]
# 18746it [00:00, 48223.87it/s]
# 18754it [00:00, 48618.93it/s]
# 18760it [00:00, 48046.95it/s]
# 18765it [00:00, 47718.14it/s]
# 18770it [00:00, 47862.89it/s]
# 18774it [00:00, 46750.88it/s]
# 18778it [00:00, 46315.35it/s]
# 18781it [00:00, 46303.28it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
r, R, n, r_max = main.r_max_vs_fwhm()
# Out:
# 19561it [00:00, 63377.36it/s]
# 19384it [00:00, 61755.90it/s]
# 19171it [00:00, 56299.76it/s]
# 19005it [00:00, 49365.81it/s]
# 18883it [00:00, 52639.41it/s]
# 18805it [00:00, 50501.85it/s]
# 18758it [00:00, 48689.88it/s]
# 18737it [00:00, 50577.07it/s]
# 18734it [00:00, 48088.21it/s]
# 18745it [00:00, 46849.84it/s]
# 18763it [00:00, 44237.88it/s]
# 18787it [00:00, 41012.65it/s]
# 18812it [00:00, 42538.91it/s]
# 18839it [00:00, 38955.78it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
r, R, n, r_max = main.r_max_vs_tau()
# Out:
# 5827it [00:00, 35787.70it/s]
# 7642it [00:00, 48659.77it/s]
# 9334it [00:00, 50249.88it/s]
# 10911it [00:00, 48331.62it/s]
# 13359it [00:00, 50549.28it/s]
# 14957it [00:00, 49410.63it/s]
# 16507it [00:00, 48841.61it/s]
# 18011it [00:00, 47904.89it/s]
# 19472it [00:00, 48580.32it/s]
# 20891it [00:00, 50969.18it/s]
# 22272it [00:00, 49041.22it/s]
# 24689it [00:00, 47678.21it/s]
# 26090it [00:00, 49085.50it/s]
# 27465it [00:00, 48217.78it/s]
# 28812it [00:00, 51339.08it/s]
# 30134it [00:00, 51004.07it/s]
# 31432it [00:00, 50629.48it/s]
# 32706it [00:00, 46932.11it/s]
# 33956it [00:00, 48066.44it/s]
# 35185it [00:00, 48403.08it/s]
# 36392it [00:00, 50627.38it/s]
# 38706it [00:00, 50581.05it/s]
# 39921it [00:00, 50553.59it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
r, R, n, r_max = main.r_max_vs_sigma()
# Out:
# 18736it [00:00, 49678.94it/s]
# 18738it [00:00, 49623.88it/s]
# 18738it [00:00, 49027.18it/s]
# 18738it [00:00, 50134.29it/s]
# 18739it [00:00, 50483.51it/s]
# 18740it [00:00, 50133.15it/s]
# 18741it [00:00, 47387.11it/s]
# 18743it [00:00, 47873.24it/s]
# 18745it [00:00, 47180.09it/s]
# 18746it [00:00, 47544.38it/s]
# 18748it [00:00, 47953.70it/s]
# 18750it [00:00, 48303.64it/s]
# 18752it [00:00, 50048.93it/s]
# 18753it [00:00, 46432.37it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pr.tau_out
# Out:
# 0.00018973998594518622
