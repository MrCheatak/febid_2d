# %%
import numpy as np
import matplotlib.pyplot as plt
from processclass import Experiment2D
from program import loop_param, plot, plot_r_max
from main import get_r_max, get_peak, get_peak_twinning, get_r_maxes

# %%
pr = Experiment2D()
# Initializing model
pr.n0 = 2.7  # 1/nm^2
pr.F = 730.0  # 1/nm^2/s
pr.s = 1.0
pr.V = 0.05  # nm^3
pr.tau = 200e-6  # s
pr.D = 8e5  # nm^2/s
pr.sigma = 0.02  # nm^2
pr.f0 = 1.0e7
pr.fwhm = 50  # nm
pr.order = 1
pr.step = 0.5  # nm

# %%
vals = np.arange(0, 2.1e6, 1e5)
param_name = 'D'
exps = loop_param(param_name, vals, pr)
r_max, twin_peak = get_r_maxes(exps)
# Out:
# 500it [00:00, 50010.78it/s]
# 2147it [00:00, 45521.35it/s]
# 3657it [00:00, 50791.82it/s]
# 5047it [00:00, 48528.58it/s]
# 6331it [00:00, 49583.67it/s]
# 7526it [00:00, 50441.40it/s]
# 8643it [00:00, 48556.84it/s]
# 9694it [00:00, 49368.48it/s]
# 10685it [00:00, 50396.83it/s]
# 11624it [00:00, 48835.56it/s]
# 12515it [00:00, 50522.55it/s]
# 13364it [00:00, 48748.11it/s]
# 14173it [00:00, 49564.70it/s]
# 14945it [00:00, 49032.61it/s]
# 15685it [00:00, 47664.51it/s]
# 16393it [00:00, 48060.03it/s]
# 17073it [00:00, 48815.73it/s]
# 17726it [00:00, 47650.02it/s]
# 18354it [00:00, 49443.35it/s]
# 18958it [00:00, 49474.59it/s]
# 19540it [00:00, 49357.53it/s]

# %%
r_max, twin_peak = get_r_maxes(exps)

# %%
plot(exps, param_name, 'p_i', 'Diffusion path at the beam center vs Residence time', twin_peak)

# %%
plot(exps, param_name, 'p_o', 'Diffusion path outside of BIR vs Residence time', twin_peak)

# %%
plot(exps, param_name, 'tau_r', 'Relative depletion vs Residence time', twin_peak)

# %%
plot(exps, 'p_o', 'tau_r', 'Relative depletion vs diff. path outside BIR', r_max)

# %%
plot_r_max(exps, r_max, param_name, 'Peak position vs diffusion coefficient', r_max)

# %%
plot_r_max(exps, r_max, 'p_i', 'Peak position vs diffusion path at the beam center', twin_peak)

# %%
plot_r_max(exps, r_max, 'p_o', 'Peak position vs diffusion path outside of BIR', twin_peak)

# %%
plot_r_max(exps, r_max, 'tau_r', 'Peak position vs diffusion path outside of BIR', twin_peak)
